# %%
# 검증하려는 영상의 경로를 입력하세요. 샘플영상이 없다면 sample폴더의 영상을 사용하세요.
mp4_path = "/Users/jinmh/Desktop/CP1/sample/sample2.mp4"

# models의 가중치(best.pt)의 경로를 입력하세요.
weights_path = "/Users/jinmh/Desktop/CP1/models/best.pt"

# 결과물이 저장되는 경로를 입력하세요.
results = "/Users/jinmh/Desktop/CP1/results"

# 경로를 수정했으면 다음 코드를 실행하세요.
# !python3 /Users/jinmh/Desktop/CP1/yolov5/detect.py --source "{mp4_path}" --weights "{weights_path}" --project "{results}"
# Out:
# detect: weights=['/Users/jinmh/Desktop/CP1/models/best.pt'], source=/Users/jinmh/Desktop/CP1/sample/sample2.mp4, data=../yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/Users/jinmh/Desktop/CP1/results, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.8.16 torch-2.0.0 CPU
#
# Fusing layers...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model summary: 157 layers, 7015519 parameters, 0 gradients
# video 1/1 (1/357) /Users/jinmh/Desktop/CP1/sample/sample2.mp4: 640x384 1 불법차량, 311.8ms
# video 1/1 (2/357) /Users/jinmh/Desktop/CP1/sample/sample2.mp4: 640x384 (no detections), 274.7ms
# ...

# %% [markdown]
# 결과물 파일은 Results saved to /Users/jinmh/Desktop/CP1/results/exp 을 확인해주세요.
# CP1/results 에 있습니다.
